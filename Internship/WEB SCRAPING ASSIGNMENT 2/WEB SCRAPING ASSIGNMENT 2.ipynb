# %%
# WEB SCRAPING

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
#Importing requests
import requests
import time
# importing regex
import re

# %%
from selenium import webdriver

# %%
#question 1

# %%
# to open the webpage through our web drivers
driver = webdriver.Chrome()
#to get url
driver.get('https://www.shine.com/')

# %%
popup=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/button')
popup.click()

# %%
#clicking on search bar
designation=driver.find_element(By.XPATH,'//input[@class="searchBarInput"]')
designation.click()

# %%
#finding elements for job search bar
designations=driver.find_element(By.CLASS_NAME,"form-control  ")
designations.send_keys('Data Analyst')

# %%
#finding elements for job search bar
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
exprience_required=[]

# %%
# to close register pop up
popup1=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div/div/button')
popup1.click()

# %%
# finding the xpath for job titles
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
# finding the xpath for location    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
# finding the xpath for company name   
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
#scraping exprience required    
exprience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in exprience_tags[0:10]:
    exprience=i.text
    exprience_required.append(exprience)

# %%
print(len(job_title),len(job_location),len(company_name),len(exprience_required))
# Out:
# 10 10 10 10

# %%
#making of dataframe from collected data
df=pd.DataFrame({'title':job_title,'location':job_location,'company_name':company_name,'exprience':exprience_required})
df
# Out:
#                                 title        location  \
# 0  Project Coordinator (Data Analyst)       Bangalore
# 1          Data Analyst - Java/Python       Bangalore
# 2             Hiring For Data Analyst  Bangalore\n+14
# 3                 Senior Data Analyst       Bangalore
# 4                        Data Analyst   Bangalore\n+9
# 5      Data Analyst Urgent Recruiment  Bangalore\n+14
# 6            Apply Now a Data Analyst       Bangalore
# 7              Apply Now Data Analyst       Bangalore
# 8             Needed for Data Analyst       Bangalore
# 9        Urgently need a Data Analyst       Bangalore
#
#                              company_name    exprience
# 0                     futures and careers   2 to 4 Yrs
# 1  boyen haddin consulting and technol...   3 to 6 Yrs
# 2                kavya staffing solutions   0 to 4 Yrs
# 3           ara resources private limited   2 to 5 Yrs
# 4  ashutosh sabhashankar chaturvedi hi...  7 to 12 Yrs
# ...

# %%
driver.close()

# %%
#question 2

# %%
#connect  to web driver
driver = webdriver.Chrome()
#to get url
driver.get('https://www.shine.com/')

# %%
# to close login pop up
popup=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/button')
popup.click()

# %%
#clicking on search bar
designation=driver.find_element(By.XPATH,'//input[@class="searchBarInput"]')
designation.click()

# %%
#sending job title input 
designations=driver.find_element(By.CLASS_NAME,"form-control  ")
designations.send_keys('Data Scientist')

# %%
#sending job location in search bar
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
#clicking on seach button
search1=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div[1]/form/div/div[2]/div/button')
search1.click()

# %%
Job_title=[]
Job_location=[]
Company_name=[]

# %%
# to register pop up
popup1=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div/div/button')
popup1.click()

# %%
# scraping job title
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    Job_title.append(title)
# scraping location    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    Job_location.append(location)
    
#scraping company name    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    Company_name.append(company)

# %%
print(len(Job_title),len(Job_location),len(Company_name))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'title':Job_title,'location':Job_location,'company_name':Company_name})
df
# Out:
#                                 title        location  \
# 0           Hiring For Data Scientist  Bangalore\n+17
# 1           Hiring For Data Scientist  Bangalore\n+17
# 2                      Data Scientist       Bangalore
# 3   Data Scientist Urgent Recruitment  Bangalore\n+14
# 4         Required for Data Scientist       Bangalore
# 5        Urgently need Data Scientist   Bangalore\n+8
# 6            Data scientist Bangalore       Bangalore
# 7                      Data Scientist       Bangalore
# 8           Hiring For Data Scientist  Bangalore\n+15
# 9  Needed for the post Data Scientist   Bangalore\n+8
#
#                              company_name
# 0                kavya staffing solutions
# 1                kavya staffing solutions
# 2                     skyleaf consultants
# 3                       divya interprises
# 4       deuglo infosystem private limited
# 5       deuglo infosystem private limited
# 6  seven geomax consulting private lim...
# ...

# %%
driver.close()

# %%
#question 4

# %%
#connect to webdriver
driver = webdriver.Chrome()
time.sleep(2)

#to get url
driver.get('https://www.flipkart.com/')

# %%
# to close login pop up
driver.find_element(By.XPATH,"//button[@class='_2KpZ6l _2doB4z']").click()

# %%
#finding elements for job search bar
search_job = driver.find_element(By.CLASS_NAME,'_3704LK')
search_job.send_keys("sunglasses")

# %%
#clicking on search button 
search_button = driver.find_element(By.XPATH,"//button[@class='L0Z3Pu']").click()

# %%
url ='https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
#to get url
driver.get(url)

# %%
element_list = []

for page in range (0,4):
    page_url = "https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+ str(page)
    driver = webdriver.Chrome()
    driver.get(page_url)
    brand_tag = driver.find_elements(By.CLASS_NAME,'_2WkVRV')
    product_tag = driver.find_elements(By.CLASS_NAME,'IRpwTa')
    price_tag = driver.find_elements(By.CLASS_NAME,'_30jeq3')
    
    for i in range(len(brand_tag)):
        element_list.append([brand_tag[i].text,product_tag[i].text,price_tag[i].text])
element_list
# Out:
# [['VINCENT CHASE',
#   'UV Protection, Polarized Over-sized Sunglasses (50)',
#   '₹899'],
#  ['VINCENT CHASE', 'Polarized, UV Protection Round Sunglasses (51)', '₹965'],
#  ['SRPM', 'UV Protection Wayfarer Sunglasses (50)', '₹204'],
#  ['PIRASO', 'UV Protection Clubmaster Sunglasses (54)', '₹239'],
#  ['Elligator',
#   'UV Protection Cat-eye, Retro Square, Oval, Round Sungla...',
#   '₹179'],
#  ['Elligator', 'UV Protection, Mirrored Wayfarer Sunglasses (54)', '₹199'],
#  ['Rich Club', 'UV Protection Retro Square Sunglasses (54)', '₹495'],
#  ['VINCENT CHASE', 'Polarized, UV Protection Round Sunglasses (50)', '₹883'],
#  ['Fastrack', 'UV Protection Wayfarer Sunglasses (58)', '₹769'],
#  ['Fastrack', 'UV Protection Rectangular Sunglasses (Free Size)', '₹629'],
#  ['ROYAL SON',
#   'UV Protection Rectangular, Retro Square Sunglasses (58)',
#   '₹497'],
#  ['agera', 'UV Protection, Gradient Aviator Sunglasses (55)', '₹240'],
# ...

# %%
sunglass = pd.DataFrame(element_list)
sunglass.columns = ['Brand','Product Description','Price']
sunglass[:100]
# Out:
#             Brand                                Product Description   Price
# 0   VINCENT CHASE  UV Protection, Polarized Over-sized Sunglasses...    ₹899
# 1   VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)    ₹965
# 2            SRPM             UV Protection Wayfarer Sunglasses (50)    ₹204
# 3          PIRASO           UV Protection Clubmaster Sunglasses (54)    ₹239
# 4       Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...    ₹179
# ..            ...                                                ...     ...
# 95       Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...    ₹699
# 96         GANSTA  Riding Glasses, UV Protection Aviator Sunglass...    ₹301
# 97    Eyewearlabs  Polarized, UV Protection Rectangular Sunglasse...  ₹2,199
# 98  VINCENT CHASE  by Lenskart Polarized, UV Protection Wayfarer ...    ₹699
# 99         GANSTA  Riding Glasses, UV Protection Aviator Sunglass...    ₹199
#
# [100 rows x 3 columns]

# %%
driver.close()

# %%
#question 5

# %%
# get drivers
driver = webdriver.Chrome()
time.sleep(2)

# %%
#getting url
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
# to find all elements and from different pages and save them in list
element_list1 = []

for page in range (0,14):
    page_url = "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGR3IXQLM&marketplace=FLIPKART&page="+ str(page)
    driver = webdriver.Chrome()
    driver.get(page_url)
    rating_tag = driver.find_elements(By.XPATH,".//div[@class='row']//div[@class='_3LWZlK _1BLPMq']")
    summary_tag = driver.find_elements(By.CLASS_NAME,'_2-N8zT')
    review_tag = driver.find_elements(By.CLASS_NAME,'t-ZTKy')
    
    for i in range(len(rating_tag)):
        element_list1.append([rating_tag[i].text,summary_tag[i].text,review_tag[i].text])
element_list1
# Out:
# [['5', 'Classy product', 'Photos super'],
#  ['5',
#   'Classy product',
#   'Camera is awesome\nBest battery backup\nA performer 👌🏻\nIt will be a real value for money if they provide charger and earphone inbox!'],
#  ['5', 'Terrific', 'Very very good'],
#  ['5', 'Wonderful', 'This is amazing at all'],
#  ['5', 'Perfect product!', 'V Good all'],
#  ['5',
#   'Worth every penny',
#   'Feeling awesome after getting the delivery of my phone. Dual speakers makes the sound quality very loud. Amazing!!'],
#  ['5', 'Best in the market!', 'Good Camera'],
#  ['5', 'Just wow!', 'Perfect Product!!'],
#  ['5', 'Fabulous!', 'Super🔥 and good performance 👌❤️'],
#  ['5', 'Great product', 'Purple is best'],
#  ['5', 'Must buy!', 'It’s really awesome'],
#  ['4', 'Worth the money', 'Camera is just wow 👌👌'],
#  ['5',
#   'Must buy!',
# ...

# %%
# making dataframe
iphone11 = pd.DataFrame(element_list1)
iphone11.columns = ['Ratings','Review Summary','Full Review']
iphone11[:100]
# Out:
#    Ratings     Review Summary  \
# 0        5     Classy product
# 1        5     Classy product
# 2        5           Terrific
# 3        5          Wonderful
# 4        5   Perfect product!
# ..     ...                ...
# 95       5          Brilliant
# 96       5          Brilliant
# 97       5   Perfect product!
# 98       5  Worth every penny
# 99       5     Classy product
#
#                                           Full Review
# 0                                        Photos super
# 1   Camera is awesome\nBest battery backup\nA perf...
# 2                                      Very very good
# 3                              This is amazing at all
# 4                                          V Good all
# ..                                                ...
# 95                                         Best phone
# 96  Perfect iPhone on this budget!! Camera and the...
# 97  Battery backup is extraordinary, camera is dec...
# ...

# %%
#question 6

# %%
#connect to webdriver
driver = webdriver.Chrome()
time.sleep(2)

#to get url
driver.get('https://www.flipkart.com/')

# %%
# to close login pop up
driver.find_element(By.XPATH,"//button[@class='_2KpZ6l _2doB4z']").click()

# %%
#finding elements for sneaker search bar
search_job = driver.find_element(By.CLASS_NAME,'_3704LK')
search_job.send_keys("sneaker")

# %%
search_button = driver.find_element(By.XPATH,"//button[@class='L0Z3Pu']").click()

# %%
url ='https://www.flipkart.com/search?q=sneaker&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
#to get url
driver.get(url)

# %%
# to find all elements and from different pages and save them in list
element_list3 = []

for page in range (0,4):
    page_url = "https://www.flipkart.com/search?q=sneaker&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=" + str(page)
    driver = webdriver.Chrome()
    driver.get(page_url)
    brand_tag = driver.find_elements(By.CLASS_NAME,'_2WkVRV')
    product_tag = driver.find_elements(By.CLASS_NAME,'IRpwTa')
    price_tag = driver.find_elements(By.CLASS_NAME,'_30jeq3')
    
    for i in range(len(brand_tag)):
        element_list3.append([brand_tag[i].text,product_tag[i].text,price_tag[i].text])
element_list3
# Out:
# [['Magnolia', 'Modern Trendy Sneakers boot Sneakers Sneakers For Men', '₹449'],
#  ['ATOM', 'Sneakers For Men', '₹1,485'],
#  ['BRUTON', 'Modern Trendy Shoes Sneakers For Men', '₹379'],
#  ['Nobelite', 'Sneakers For Men', '₹299'],
#  ['aadi',
#   'Synthetic Leather |Lightweight|Comfort|Summer|Trendy|Wa...',
#   '₹398'],
#  ['PUMA', 'Puma Rebound LayUp SL Sneakers For Men', '₹1,930'],
#  ['Schuster', 'Sneakers For Men', '₹549'],
#  ['RapidBox', 'Sneakers For Men', '₹750'],
#  ['PUMA', 'UP Sneakers For Men', '₹1,508'],
#  ['PUMA', 'Rebound LayUp SL Sneakers For Men', '₹2,649'],
#  ['ATOM', 'Sneakers For Men', '₹1,485'],
#  ['asian',
#   'asian Thunder-01 White Color Change Sneakers,Casuals,Lo...',
#   '₹940'],
#  ['Sparx', 'Sneakers For Men', '₹519'],
#  ['Sparx', 'Men White Sneakers Sneakers For Men', '₹629'],
#  ['aadi',
#   'Lightweight,Comfort,Summer,Trendy,Walking,Outdoor,Styli...',
#   '₹299'],
#  ['PUMA', 'Hustle V2 Sneakers For Men', '₹1,299'],
# ...

# %%
#making of dataframe
sneakers = pd.DataFrame(element_list3)
sneakers.columns = ['Brand','Product Description','Price']
sneakers[:100]
# Out:
#               Brand                                Product Description   Price
# 0          Magnolia  Modern Trendy Sneakers boot Sneakers Sneakers ...    ₹449
# 1              ATOM                                   Sneakers For Men  ₹1,485
# 2            BRUTON               Modern Trendy Shoes Sneakers For Men    ₹379
# 3          Nobelite                                   Sneakers For Men    ₹299
# 4              aadi  Synthetic Leather |Lightweight|Comfort|Summer|...    ₹398
# ..              ...                                                ...     ...
# 95  U.S. POLO ASSN.                           CLARKIN Sneakers For Men  ₹1,795
# 96            asian  asian Thunder-01 White Color Change Sneakers,C...    ₹940
# 97         Magnolia                                   Sneakers For Men    ₹449
# 98         RED TAPE                                   Sneakers For Men  ₹1,399
# 99           BRUTON           Exclusive Sneaker Shoes Sneakers For Men    ₹349
#
# [100 rows x 3 columns]

# %%
driver.close()

# %%
#question 7

# %%
driver=webdriver.Chrome()
# get url
driver.get("https://www.amazon.in/")

# %%
# enter “laptop” in the search field.
search_product = driver.find_element(By.XPATH,"//div[@class='nav-search-field ']/input")
search_product.send_keys("laptop")

# %%
# click the search button
search_btn = driver.find_element(By.XPATH,"//div[@class='nav-search-submit nav-sprite']")
search_btn.click()

# %%
# applying CPU Type filter to “Intel Core i7” filter by checking the respective box
i7_clk=driver.find_elements(By.XPATH,"//span[@class='a-size-base a-color-base']")
for i in i7_clk:
    if i.text == 'Intel Core i7':   
        i.click() # Checking the checkbox to apply filter on the laptop
        break

# %%
# creating empty list to scraping data into them

Title=[]
Rating=[]
Price=[]

# extracting all the tags

titles=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
for i in titles:
    Title.append(i.text)
    
titles_rat=driver.find_elements(By.XPATH,"//div[@class='a-row a-size-small']/span")
for i in titles_rat:
    Rating.append(i.get_attribute("aria-label"))
        
titles_Price=driver.find_elements(By.XPATH,"//span[@class='a-price']")
for i in titles_Price:
    Price.append(i.text[1:])

# %%
# extratcing ratings from the unorganised rating tag

rating=[]
for i in range(0,len(Rating)):
    if i == 0 or  i/2 == i//2:
        rating.append(Rating[i][0:3])

# %%
# creating dataframe for the first 10 laptops data on amazon.com:

amazon =pd.DataFrame({})
amazon['Title']=Title[0:10]
amazon['Rating']=rating[0:10]
amazon['Price']=Price[0:10]

print("The data for the first 10 i7 laptops data on amazon.com:\n")
amazon
# Out:
# The data for the first 10 i7 laptops data on amazon.com:
#                                                Title Rating   Price
# 0  MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...    4.5  70,990
# 1  ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...    4.0  64,990
# 2  Dell Vostro 5630 13th Gen Laptop,Intel i7-1355...    4.6  89,990
# 3  ASUS TUF Gaming F15, 15.6-inch (39.62 cms) FHD...    3.3  89,990
# 4  Dell Inspiron 5430 13th Gen Laptop, Intel i7-1...    4.0  86,249
# 5  MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...    3.3  52,990
# 6  Acer Nitro 5 12th Gen Intel Core i7-12650H Gam...    4.3  99,990
# 7  Lenovo [SmartChoice] IdeaPad Slim 3 Intel Core...    3.6  62,990
# 8  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...    4.4  80,990
# 9  Dell Inspiron 5630 13th Gen Laptop, Intel Core...    2.9  89,990

# %%
driver.close()

# %%
#question 8

# %%
#connect to webdriver
driver = webdriver.Chrome()
time.sleep(2)

#to get url
driver.get('https://www.azquotes.com/')

# %%
#clicking on top quotes
quotes=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
quotes.click()

# %%
url ='https://www.azquotes.com/top_quotes.html'
#to get url
driver.get(url)

# %%
element_list4 = []

for page in range (0,25):
    page_url = "https://www.azquotes.com/top_quotes.html&page="+ str(page)
    driver = webdriver.Chrome()
    driver.get(page_url)
    quotes_tag = driver.find_elements(By.CLASS_NAME,'title')
    author_tag = driver.find_elements(By.CLASS_NAME,'author')
    types_of_quotes_tag = driver.find_elements(By.CLASS_NAME,'tags')
    
    for i in range(len(brand_tag)):
        element_list4.append([quotes_tag[i].text,author_tag[i].text,types_of_quotes_tag[i].text])
element_list4
# Out:
# [['Authors:', 'Michael Porter', 'Essence, Deep Thought, Transcendentalism'],
#  ['The essence of strategy is choosing what not to do.',
#   'Golda Meir',
#   'Inspiration, Past, Trying'],
#  ['One cannot and must not try to erase the past merely because it does not fit the present.',
#   'Theodore Roosevelt',
#   'Country, Peace, War'],
#  ['Patriotism means to stand by the country. It does not mean to stand by the president.',
#   'Nelson Mandela',
#   'Inspirational, Motivational, Death'],
#  ['Death is something inevitable. When a man has done what he considers to be his duty to his people and his country, he can rest in peace. I believe I have made that effort and that is, therefore, why I will sleep for the eternity.',
#   'Erma Bombeck',
#   '4th Of July, Food, Patriotic'],
# ...

# %%
topquotes= pd.DataFrame(element_list4)
topquotes.columns = ['quotes','author','types_of_quotes']
topquotes[:1000]
# Out:
#                                                 quotes                author  \
# 0                                             Authors:        Michael Porter
# 1    The essence of strategy is choosing what not t...            Golda Meir
# 2    One cannot and must not try to erase the past ...    Theodore Roosevelt
# 3    Patriotism means to stand by the country. It d...        Nelson Mandela
# 4    Death is something inevitable. When a man has ...          Erma Bombeck
# ..                                                 ...                   ...
# 995  Good actions are a guard against the blows of ...            Zig Ziglar
# 996  Positive thinking will let you do everything b...     Winston Churchill
# 997  You have enemies? Good. That means you've stoo...            Zig Ziglar
# 998  You don't have to be great to start, but you h...       John F. Kennedy
# 999  Let every nation know, whether it wishes us we...  Dwight D. Eisenhower
#
# ...

# %%
#question 10

# %%
#connect to webdriver
driver = webdriver.Chrome()
time.sleep(2)

#to get url
driver.get('https://www.motor1.com/')

# %%
#clicking on search bar 
search=driver.find_element(By.XPATH,"/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/input")
search.click()

# %%
#sending input
cars=driver.find_element(By.XPATH,'//input[@class="m1-search-panel-input m1-search-form-text"]')
cars.send_keys('50 most expensive cars')

# %%
#clicking on search 
search1=driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/button[1]')
search1.click()

# %%
#clicking on cars
search1=driver.find_element(By.XPATH,'/html/body/div[10]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a')
search1.click()

# %%
car_name=[]
price=[]

# %%
# scraping car namr
car_tags=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in car_tags[0:50]:
    car=i.text
    car_name.append(car)
# scraping car price    
price_tags=driver.find_elements(By.XPATH,'//p/strong')
for i in price_tags[0:50]:
    price1=i.text
    price.append(price1)

# %%
print(len(car_name),len(price))
# Out:
# 50 50

# %%
df=pd.DataFrame({'cars_name':car_name,'price':price})
df
# Out:
#                              cars_name                        price
# 0                  Aston Martin Valour          Price: $1.5 Million
# 1                         McLaren Elva          Price: $1.7 Million
# 2                          Czinger 21C          Price: $1.7 Million
# 3                        Ferrari Monza          Price: $1.7 Million
# 4                   Gordon Murray T.33          Price: $1.7 Million
# 5                    Koenigsegg Gemera          Price: $1.7 Million
# 6                          Zenvo TSR-S          Price: $1.7 Million
# 7                   Hennessey Venom F5          Price: $1.8 Million
# 8                      Bentley Bacalar          Price: $1.9 Million
# 9        Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 10              Bentley Mulliner Batur          Price: $2.0 Million
# 11                        Deus Vayanne          Price: $2.0 Million
# 12                         SSC Tuatara          Price: $2.0 Million
# ...

# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=ad762307afbf5d7f801ff11fe0fa3651600f0e20c94be436e9de8c243148fa70
#   Stored in directory: c:\users\vijay\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#Question 1

# %%
import requests
from bs4 import BeautifulSoup

def extract_headers(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  

        soup = BeautifulSoup(response.content, 'html.parser')
        headers = []

        for header_level in range(1, 7): 
            header_tags = soup.find_all(f'h{header_level}')
            for header_tag in header_tags:
                headers.append({
                    'level': header_level,
                    'text': header_tag.get_text(strip=True)
                })

        return headers

    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return []

if __name__ == "__main__":
    website_url = "https://en.wikipedia.org/wiki/Main_Page"  
    extracted_headers = extract_headers(website_url)

    for header in extracted_headers:
        print(f"Header : {header['text']}")
# Out:
# Header : Main Page
# Header : Welcome toWikipedia
# Header : From today's featured article
# Header : Did you know ...
# Header : In the news
# Header : On this day
# Header : Today's featured picture
# Header : Other areas of Wikipedia
# Header : Wikipedia's sister projects
# Header : Wikipedia languages

# %%
#Question 3

# %%
(a)

# %%
def data1(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    teams = []
    table = soup.find('table', class_='table')
    rows = table.find_all('tr')

    for row in rows[1:11]:  
        cols = row.find_all('td')
        team = {
            'Rank': cols[0].get_text(strip=True),
            'Team': cols[1].get_text(strip=True),
            'Matches': cols[2].get_text(strip=True),
            'Points': cols[3].get_text(strip=True),
            'Rating': cols[4].get_text(strip=True)
        }
        teams.append(team)

    return teams

def scrape_odi_players(url, category):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    players = []
    table = soup.find('table', class_='table')
    rows = table.find_all('tr')

    for row in rows[1:11]:  
        cols = row.find_all('td')
        player = {
            'Rank': cols[0].get_text(strip=True),
            'Player': cols[1].get_text(strip=True),
            'Team': cols[2].get_text(strip=True),
            'Rating': cols[3].get_text(strip=True)
        }
        players.append(player)

    return players

if __name__ == "__main__":
    base_url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
    
    # top 10 ODI teams
    teams_url = base_url
    odi_teams = data1 (teams_url)
    odi_teams_df = pd.DataFrame(odi_teams)
    
    print("Top 10 ODI Teams:")
    print(odi_teams_df)
# Out:
# Top 10 ODI Teams:
#   Rank            Team Matches Points Rating
# 0    1    AustraliaAUS      23  2,714    118
# 1    2     PakistanPAK      20  2,316    116
# 2    3        IndiaIND      36  4,081    113
# 3    4   New ZealandNZ      27  2,806    104
# 4    5      EnglandENG      24  2,426    101
# 5    6  South AfricaSA      19  1,910    101
# 6    7   BangladeshBAN      28  2,661     95
# 7    8  AfghanistanAFG      16  1,404     88
# 8    9     Sri LankaSL      32  2,794     87
# 9   10   West IndiesWI      38  2,582     68

# %%
(b)

# %%
def data(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    batsmen = []
    table = soup.find('table', class_='table')
    rows = table.find_all('tr')

    for row in rows[1:11]: 
        cols = row.find_all('td')
        batsman = {
            'Rank': cols[0].get_text(strip=True),
            'Player': cols[1].get_text(strip=True),
            'Team': cols[2].get_text(strip=True),
            'Rating': cols[3].get_text(strip=True)
        }
        batsmen.append(batsman)

    return batsmen

if __name__ == "__main__":
    base_url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
    
    # top 10 ODI Batsmen
    odi_batsmen = data(base_url)
    odi_batsmen_df = pd.DataFrame(odi_batsmen)
    
    print("Top 10 ODI Batsmen:")
    print(odi_batsmen_df)
# Out:
# Top 10 ODI Batsmen:
#                                                 Rank                 Player  \
# 0                                               1(0)             Babar Azam
# 1                                               2(0)  Rassie van der Dussen
# 2                                               3(0)           Fakhar Zaman
# 3                                               4(0)            Imam-ul-Haq
# 4  5(2)This player has moved up in the rankings s...           Shubman Gill
# 5  6(1)This player has moved down in the rankings...           Harry Tector
# 6  =(1)This player has moved down in the rankings...           David Warner
# 7                                               8(0)        Quinton de Kock
# 8                                               9(0)            Virat Kohli
# 9                                              10(0)            Steve Smith
#
#   Team Rating
# 0  PAK    886
# 1   SA    777
# 2  PAK    755
# 3  PAK    745
# 4  IND    743
# 5  IRE    726
# ...

# %%
(c)

# %%
def data(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    bowlers = []
    table = soup.find('table', class_='table')
    rows = table.find_all('tr')

    for row in rows[1:11]:  
        cols = row.find_all('td')
        bowler = {
            'Rank': cols[0].get_text(strip=True),
            'Player': cols[1].get_text(strip=True),
            'Team': cols[2].get_text(strip=True),
            'Rating': cols[3].get_text(strip=True)
        }
        bowlers.append(bowler)

    return bowlers

if __name__ == "__main__":
    base_url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling"
    
    # top 10 ODI Bowlers
    odi_bowlers = data(base_url)
    odi_bowlers_df = pd.DataFrame(odi_bowlers)
    
    print("Top 10 ODI Bowlers:")
    print(odi_bowlers_df)
# Out:
# Top 10 ODI Bowlers:
#                                                 Rank            Player Team  \
# 0                                               1(0)    Josh Hazlewood  AUS
# 1                                               2(0)    Mitchell Starc  AUS
# 2                                               3(0)       Rashid Khan  AFG
# 3                                               4(0)    Mohammed Siraj  IND
# 4                                               5(0)        Matt Henry   NZ
# 5                                               6(0)  Mujeeb Ur Rahman  AFG
# 6                                               7(0)       Trent Boult   NZ
# 7                                               8(0)        Adam Zampa  AUS
# 8                                               9(0)    Shaheen Afridi  PAK
# 9  10(4)This player has moved up in the rankings ...     Kuldeep Yadav  IND
#
#   Rating
# 0    705
# 1    686
# 2    682
# 3    670
# 4    667
# 5    661
# 6    660
# 7    652
# 8    630
# ...

# %%
#Question 4

# %%
url='https://www.icc-cricket.com/rankings/womens/team-rankings/odi'
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Women\'s ODI Team Rankings | ICC"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Women\'s ODI Team Rankings | ICC"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/ele
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup.title.text
# Out:
# "ICC Women's ODI Team Rankings | ICC"

# %%
WMatch=[]
for i in soup.find_all('td',class_='rankings-block__banner--matches'):
    WMatch.append(i.text)

# %%
WMatch
# Out:
# ['26']

# %%
WMatches=[]
for i in soup.find_all('td',class_='table-body__cell u-center-text'):
    WMatches.append(i.text)

#WMatches

# %%
Wpoint=[]

for i in soup.find_all('td',class_='rankings-block__banner--points'):
    Wpoint.append(i.text)
Wpoint
# Out:
# ['4,290']

# %%
Wpoints=[]

for i in soup.find_all('td',class_='table-body__cell u-center-text'):
    Wpoints.append(i.text)
Wpoints
# Out:
# ['31',
#  '3,875',
#  '26',
#  '3,098',
#  '30',
#  '3,039',
#  '28',
#  '2,688',
#  '29',
#  '2,743',
#  '17',
#  '1,284',
#  '12',
#  '820',
#  '13',
#  '883',
#  '27',
#  '1,678',
#  '18',
#  '660',
#  '11',
#  '89',
#  '11',
#  '0']

# %%
WRating=[]

for i in soup.find_all('td',class_='rankings-block__banner--rating u-text-right'):
    WRating.append(i.text[29:32])
WRating
# Out:
# ['165']

# %%
WRatings=[]

for i in soup.find_all('td',class_='table-body__cell u-text-right rating'):
    WRatings.append(i.text)
    
WRatings
# Out:
# ['125', '119', '101', '96', '95', '76', '68', '68', '62', '37', '8', '0']

# %%
df = pd.DataFrame({'Women_Teams':['Australia','South Africa','England','India','Bangladesh','New Zealand','West Indies','Pakistan','Ireland','Sri Lanka',],
                   'Matches':['17','19','18','17','5','19','19','18','5','5'],
                   'Points':['2,746','2,307','2,148','1,899','475','1,668','1,658','1,226','240','233'],
                   'Ratings':['162','121', '119', '112', '95', '88', '87', '68', '48', '47']})

# %%
df.sort_values('Ratings')
# Out:
#     Women_Teams Matches Points Ratings
# 3         India      17  1,899     112
# 2       England      18  2,148     119
# 1  South Africa      19  2,307     121
# 0     Australia      17  2,746     162
# 9     Sri Lanka       5    233      47
# 8       Ireland       5    240      48
# 7      Pakistan      18  1,226      68
# 6   West Indies      19  1,658      87
# 5   New Zealand      19  1,668      88
# 4    Bangladesh       5    475      95

# %%
df
# Out:
#     Women_Teams Matches Points Ratings
# 0     Australia      17  2,746     162
# 1  South Africa      19  2,307     121
# 2       England      18  2,148     119
# 3         India      17  1,899     112
# 4    Bangladesh       5    475      95
# 5   New Zealand      19  1,668      88
# 6   West Indies      19  1,658      87
# 7      Pakistan      18  1,226      68
# 8       Ireland       5    240      48
# 9     Sri Lanka       5    233      47

# %%
url='https://www.icc-cricket.com/rankings/womens/player-rankings/odi'
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Women\'s ODI Player Rankings | ICC"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Women\'s ODI Player Rankings | ICC"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver
# ...

# %%
soup = BeautifulSoup(page.content,'html.parser')

# %%
soup.title.text
# Out:
# "ICC Women's ODI Player Rankings | ICC"

# %%
player =[]

for i in soup.find_all('div',class_='rankings-block__banner--name'):
    player.append(i.text)

player
# Out:
# ['Natalie Sciver-Brunt', 'Sophie Ecclestone', 'Natalie Sciver-Brunt']

# %%
players =[]

for i in soup.find_all('td',class_='table-body__cell name'):
    players.append(i.text.replace('\n',''))
#players

# %%
player.extend(players) # joined both list after extracting seperately.
#player

# %%
team =[]

for i in soup.find_all('div',class_='rankings-block__banner--nationality'):
    team.append(i.text[0:5].replace('\n',''))
    
team
# Out:
# ['ENG', 'ENG', 'ENG']

# %%
teams =[]

for i in soup.find_all('span',class_='table-body__logo-text'):
    teams.append(i.text)
    
#teams

# %%
team.extend(teams) #joined
#team

# %%
rating=[]

for i in soup.find_all('div',class_='rankings-block__banner--nationality'):
    rating.append(i.text[5:9].replace('\n',''))

rating
# Out:
# ['803', '769', '421']

# %%
ratings =[]
for i in soup.find_all('td',class_='table-body__cell u-text-right rating'):
    ratings.append(i.text)
#ratings

# %%
rating.extend(ratings)
#rating

# %%
data = list(zip(player,team,rating))

# %%
df = pd.DataFrame(data,columns=['Players','Teams','Ratings'])
df
# Out:
#                  Players Teams Ratings
# 0   Natalie Sciver-Brunt   ENG     803
# 1      Sophie Ecclestone   ENG     769
# 2   Natalie Sciver-Brunt   ENG     421
# 3    Chamari Athapaththu    SL     758
# 4            Beth Mooney   AUS     751
# 5        Laura Wolvaardt    SA     732
# 6        Smriti Mandhana   IND     708
# 7           Alyssa Healy   AUS     702
# 8       Harmanpreet Kaur   IND     694
# 9           Ellyse Perry   AUS     686
# 10           Meg Lanning   AUS     682
# 11       Stafanie Taylor    WI     618
# 12        Shabnim Ismail    SA     722
# 13         Jess Jonassen   AUS     682
# 14      Ashleigh Gardner   AUS     673
# 15          Megan Schutt   AUS     666
# 16       Hayley Matthews    WI     662
# 17            Kate Cross   ENG     661
# 18        Ayabonga Khaka    SA     634
# 19         Deepti Sharma   IND     607
# 20   Rajeshwari Gayakwad   IND     599
# 21      Ashleigh Gardner   AUS     389
# 22       Hayley Matthews    WI     382
# ...

# %%
df.sort_values('Ratings',ascending=False,inplace=True)

# %%
df.head(10)
# Out:
#                  Players Teams Ratings
# 0   Natalie Sciver-Brunt   ENG     803
# 1      Sophie Ecclestone   ENG     769
# 3    Chamari Athapaththu    SL     758
# 4            Beth Mooney   AUS     751
# 5        Laura Wolvaardt    SA     732
# 12        Shabnim Ismail    SA     722
# 6        Smriti Mandhana   IND     708
# 7           Alyssa Healy   AUS     702
# 8       Harmanpreet Kaur   IND     694
# 9           Ellyse Perry   AUS     686

# %%
url = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder'

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Women\'s ODI All Rounder | Player Rankings | ICC"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Women\'s ODI All Rounder | Player Rankings | ICC"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thum
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup.title.text
# Out:
# "ICC Women's ODI All Rounder | Player Rankings | ICC"

# %%
player = []

for i in soup.find_all('div',class_='rankings-block__banner--name-large'):
    player.append(i.text)
    
player
# Out:
# ['Natalie Sciver-Brunt']

# %%
players =[]

for i in soup.find_all('td', class_='table-body__cell rankings-table__name name'):
    players.append(i.text.replace('\n',''))

# %%
team =[]
for i in soup.find_all('div',class_='rankings-block__banner--nationality'):
    team.append(i.text.replace('\n',''))
    
team
# Out:
# ['ENG']

# %%
teams = []

for i in soup.find_all('span',class_='table-body__logo-text'):
    teams.append(i.text)

# %%
team.extend(teams)

# %%
rating =[]
ratings=[]

for i in soup.find_all('div', class_='rankings-block__banner--rating'):
    rating.append(i.text)
    
for i in soup.find_all('td', class_='table-body__cell rating'):
    ratings.append(i.text)

# %%
rating.extend(ratings)

# %%
data = list(zip(player,team,rating))

# %%
df=pd.DataFrame(data, columns=['Players','Teams','Rating'])
df.sort_values('Rating', ascending=False, inplace = True)

# %%
df.head(10)
# Out:
#                 Players Teams Rating
# 0  Natalie Sciver-Brunt   ENG    421

# %%
#Question 5

# %%
WTeam = []

for i in soup.find_all('span',class_='u-hide-phablet'):
    WTeam.append(i.text)
    
WTeam
# Out:
# ['Australia',
#  'England',
#  'South Africa',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Bangladesh',
#  'Sri Lanka',
#  'Thailand',
#  'Pakistan',
#  'Ireland',
#  'Netherlands',
#  'Zimbabwe']

# %%
page = requests.get('https://www.cnbc.com/world/?region=world')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)

# %%
# Headline

news_headline = []

for i in soup.find_all("a", class_='LatestNews-headline'):
    news_headline.append(i.text)

# %%
# Time

news_time = []

for i in soup.find_all("span",class_="LatestNews-wrapper"):
    news_time.append(i.text)

# %%
# News link

news_link = []

for i in soup.find_all("a", class_='LatestNews-headline'):
    news_link.append(i.get('href'))

# %%
# Making dataframe

df = pd.DataFrame({'Headline': news_headline, 'Time': news_time, 'News link': news_link})

df.index=df.index+1

df
# Out:
#                                              Headline             Time  \
# 1   Ex-software engineer brings in $129,000 a year...      2 Hours Ago
# 2   How to start investing for the long haul for t...      2 Hours Ago
# 3   'The coolest summer job': Meet Wisconsin's tee...      2 Hours Ago
# 4   With Lionel Messi playing soccer in the U.S., ...      3 Hours Ago
# 5   Young Bill Gates thought school wasn't 'intere...      3 Hours Ago
# 6   Why startups are investing millions to make dr...      3 Hours Ago
# 7   Lawmakers weigh tax rule 'backslide' for Venmo...      3 Hours Ago
# 8   Here's the trade on Nvidia ahead of earnings, ...      4 Hours Ago
# 9   Bitcoin had a big drop late last week. Here's ...      4 Hours Ago
# 10  Why 'career choices' is the No. 1 conflict amo...     22 Hours Ago
# 11  Cruise will reduce robotaxi fleet by 50% in Sa...     23 Hours Ago
# 12  Can American-made weapons like F-16s turn the ...     24 Hours Ago
# ...

# %%
#Question 6

# %%
page = requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)

# %%
# Paper title

title = []

for i in soup.find_all('h2', class_="sc-1qrq3sd-1 MKjKb sc-1nmom32-0 sc-1nmom32-1 hqhUYH ebTA-dR"):
    title.append(i.text)

# %%
# Authors

authors = []

for i in soup.find_all('span', class_="sc-1w3fpd7-0 pgLAT"):
    authors.append(i.text)

# %%
# Published date

pub_date = []

for i in soup.find_all('span', class_="sc-1thf9ly-2 bKddwo"):
    pub_date.append(i.text)

# %%
# Paper URL

paper_url = []

for i in soup.find_all("a", class_="sc-5smygv-0 nrDZj"):
    paper_url.append(i.get('href'))

# %%
print(len(title), len(authors), len(pub_date), len(paper_url))
# Out:
# 0 0 0 0

# %%
# Making dataframe

df12 = pd.DataFrame({'Paper title': title, 'Authors': authors , 'Published date': pub_date, 'Paper URL':paper_url})

df12.index=df12.index+1

df12
# Out:
# Empty DataFrame
# Columns: [Paper title, Authors, Published date, Paper URL]
# Index: []

# %%
#Question 7

# %%
page = requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)

# %%
# Restaurant name 

restaurant_name = []

for i in soup.find_all('div',class_ ='restnt-info cursor'):
    restaurant_name.append(i.text)
 
# Cuisine

cuisine = []

for i in soup.find_all('span',class_ ='double-line-ellipsis'):
    cuisine.append(i.text.replace('₹','').split('|')[1])


location=[]

for i in soup.find_all('div',class_ ='restnt-loc ellipsis'):
    location.append(i.text)
    
    
# Ratings

rating = []

for i in soup.find_all('div',class_='restnt-rating rating-4'):
    rating.append(i.text)
             
        
# Image URL

image_url = []
    
for i in soup.find_all('img',class_='no-img'):
     image_url.append(i['data-src'])

# %%
# Making dataframe

df = pd.DataFrame({'Restaurant name':restaurant_name, 'Cuisine':cuisine,'Location':location,'Rating':rating,'Image_URL':image_url})

df.index=df.index+1

df
# Out:
#                                      Restaurant name  \
# 1      Castle BarbequeConnaught Place, Central Delhi
# 2  Cafe KnoshThe Leela Ambience Convention Hotel,...
# 3  Castle's BarbequePacific Mall,Tagore Garden, W...
# 4    India GrillHilton Garden Inn,Saket, South Delhi
# 5  The Barbeque CompanyGardens Galleria,Sector 38...
# 6  Delhi BarbequeTaurus Sarovar Portico,Mahipalpu...
# 7  The Monarch - Bar Be Que VillageIndirapuram Ha...
# 8  The Barbeque TimesM2K Corporate Park,Sector 51...
# 9  Indian Grill RoomSuncity Business Tower,Golf C...
#
#                                              Cuisine  \
# 1                              Chinese, North Indian
# 2                               Italian, Continental
# 3                              Chinese, North Indian
# 4                              North Indian, Italian
# 5                              North Indian, Chinese
# 6                                       North Indian
# 7                                       North Indian
# ...
